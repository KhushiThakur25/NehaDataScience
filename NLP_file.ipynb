# %% [markdown]
# NLP - NATURAL LANGUAGE PROCESSING
# TEXT PROCESSING
#
# - Sentiments Analysis
# - Spam Classification

# %% [markdown]
# 1. Tokenization ["this","movie","was","really","very","good","and","i","enjoyed","watching","it","."]
# 2. Remove stopwords and punctuations
#     - is,are,that,this,it,and..
#     - !@#$%^&*()[]{}
# ["movie","really","very","good","enjoyed","watching"]
# 3. Lemmatization / Stemming
#     - ["movie","really","very","good","enjoy","watch"]
# 4. Vectorization
#     - CountVectorization
#     - TF - IDF - Term Frequency / Inverse Document Frequency
#     - Hashing
