# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
data = np.array([[25,50000,1],[30,80000,2],[20,30000,2],[40,90000,2],
                [45,75000,0],[35,35000,2],[45,15000,1]])
labels = np.array([0,0,1,2,1,0,1]) # 0:low 1:medium 2:high

# %%
X_train,X_test,y_train,y_test = train_test_split(data,labels,test_size=0.2,random_state = 42)
X_train,X_test
# Out:
# (array([[   35, 35000,     2],
#         [   20, 30000,     2],
#         [   45, 75000,     0],
#         [   40, 90000,     2],
#         [   45, 15000,     1]]),
#  array([[   25, 50000,     1],
#         [   30, 80000,     2]]))

# %%
scaler =  StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
X_train,X_test

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
accuracy = knn.score(X_test,y_test)
accuracy
# Out:
# 0.5

# %%
user_in = np.array([[30,30000,2]])
user_input_scaled = scaler.transform(user_in)
prediction = knn.predict(user_input_scaled)

# %%
if prediction[0] == 1:
    print("Product is buy by customer")
else:
    print("Product doesn't buy by customer")
# Out:
# Product is buy by customer
